# %%
import pandas

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

videogame_sales_data = pandas.read_csv("../best_selling_games.csv")
sales_data = videogame_sales_data.iloc[:,2]

count = 0
for num in sales_data:
    sales_data[count] = int(num.replace(",", ""))
    count += 1

videogame_sales_data
# Out:
# C:\Users\Henry\AppData\Local\Temp\ipykernel_12612\633427332.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_data[count] = int(num.replace(",", ""))
#     Unnamed: 0                                             Title      Sales  \
# 0            0                                         Minecraft  200000000
# 1            1                                Grand Theft Auto V  130000000
# 2            2                                       Tetris (EA)  100000000
# 3            3                                        Wii Sports   82900000
# 4            4                     PlayerUnknown's Battlegrounds   60000000
# 5            5                                 Super Mario Bros.   48240000
# 6            6               Pokémon Red / Green / Blue / Yellow   47520000
# 7            7                          Wii Fit and Wii Fit Plus   43800000
# 8            8                                 Tetris (Nintendo)   43000000
# 9            9                                           Pac-Man   39098000
# 10          11                             Mario Kart 8 / Deluxe   33220000
# 11          12                                 Wii Sports Resort   33130000
# 12          13                             Red Dead Redemption 2   31000000
# 13          14                             New Super Mario Bros.   30800000
# 14          15                                          Terraria   30300000
# 15          16                         New Super Mario Bros. Wii   30300000
# 16          17                       The Elder Scrolls V: Skyrim   30000000
# 17          18                    Diablo III and Reaper of Souls   30000000
# 18          19                   Pokémon Gold / Silver / Crystal   29490000
# 19          20                                         Duck Hunt   28300000
# 20          21                                          Wii Play   28020000
# 21          22  The Witcher 3 / Hearts of Stone / Blood and Wine   28000000
# 22          23                     Grand Theft Auto: San Andreas   27500000
# 23          24                    Call of Duty: Modern Warfare 3   26500000
# 24          25                           Call of Duty: Black Ops   26200000
# 25          26                               Grand Theft Auto IV   25000000
# 26          27       Pokémon Sun / Moon / Ultra Sun / Ultra Moon   24950000
# 27          28                Pokémon Diamond / Pearl / Platinum   24730000
# 28          29                        Call of Duty: Black Ops II   24200000
# 29          30                                Kinect Adventures!   24000000
# 30          31                                           FIFA 18   24000000
# 31          32                                Sonic the Hedgehog   23982960
# 32          33                                        Nintendogs   23960000
# 33          34                                     Mario Kart DS   23600000
# 34          35                    Call of Duty: Modern Warfare 2   22700000
# 35          36                 Pokémon Ruby / Sapphire / Emerald   22540000
# 36          37                                     Borderlands 2   22000000
# 37          38                                 Super Mario World   20972500
# 38          39                                           Frogger   20000000
# 39          40                                          Lemmings   20000000
# 40          41                       Grand Theft Auto: Vice City   20000000
# 41          42                                    The Last of Us   20000000
# 42          43           The Legend of Zelda: Breath of the Wild   19080000
# 43          44                                         Brain Age   19010000
# 44          45                               Super Mario Bros. 3   19000000
# 45          46                              Call of Duty: Ghosts   19000000
# 46          47                        Super Smash Bros. Ultimate   18840000
# 47          48                                      Mario Kart 7   18710000
# 48          49                                  Super Mario Land   18370500
# 49          50                                    Gran Turismo 4   17830000
#
#          Platform(s) Initial  release date                      Developer(s)  \
# 0     Multi-platform  November 18, 2011[b]                    Mojang Studios
# 8                         Nintendo
# 9                            Namco
# 10                        Nintendo
# 11                        Nintendo
# 12                  Rockstar Games
# 13                        Nintendo
# 14            Re-Logic / 505 Games
# 15                        Nintendo
# 16              Bethesda Softworks
# 17          Blizzard Entertainment
# 18                        Nintendo
# 19                        Nintendo
# 20                        Nintendo
# 21                      CD Projekt
# 22                  Rockstar Games
# 23                      Activision
# 24                      Activision
# 25                  Rockstar Games
# 26  Nintendo / The Pokémon Company
# 27  Nintendo / The Pokémon Company
# 28                      Activision
# 29               Xbox Game Studios
# 30                 Electronic Arts
# 31                            Sega
# 32                        Nintendo
# 33                        Nintendo
# 34                      Activision
# 35  Nintendo / The Pokémon Company
# 36                        2K Games
# 37                        Nintendo
# 38                            Sega
# 39                       Psygnosis
# 40                  Rockstar Games
# 41     Sony Computer Entertainment
# 42                        Nintendo
# 43                        Nintendo
# 44                        Nintendo
# 45                      Activision
# 46                        Nintendo
# 47                        Nintendo
# 48                        Nintendo
# 49     Sony Computer Entertainment

# %%
"1 | Which video game company has the most sales combined from all their video games?"
"2 | What is a noteable attribute of those in the top 20 in sales have in common?"
"3 | Which company has produced the most video games?"
"4 | Which company has made the least amount of sales?"
"5 | Which company has made the least amount of games?"
"6 | Is being muliplatform compatible that impactful in terms of sales?"
"7 | How many games are stuck to only one platform?"
"8 | How many games are multiplatform?"
"9 | Which company is least likely to make the next big game?"
"10 | Which company would be most likely to make the next big game?"
# Out:
# '10 | Which company would be most likely to make the next big game?'

# %%
'''1.) Which video game company has the most sales combined from all their video games?
'''

sales_dict = {}

for co in company:
    sales_dict[co] = videogame_sales_data.loc[videogame_sales_data["Publisher(s)"] == co]["Sales"].sum()

sales_dict

# Nintendo has the most sales
# Out:
# {'Mojang Studios': 200000000,
#  'Rockstar Games': 233500000,
#  'Electronic Arts': 124000000,
#  'Nintendo': 660263000,
#  'PUBG Corporation': 60000000,
#  'Namco': 39098000,
#  'Re-Logic / 505 Games': 30300000,
#  'Bethesda Softworks': 30000000,
#  'Blizzard Entertainment': 30000000,
#  'CD Projekt': 28000000,
#  'Activision': 118600000,
#  'Nintendo / The Pokémon Company': 72220000,
#  'Xbox Game Studios': 24000000,
#  'Sega': 43982960,
#  '2K Games': 22000000,
#  'Psygnosis': 20000000,
#  'Sony Computer Entertainment': 37830000}

# %%
"2.) What is a noteable attribute of those in the top 20 in sales have in common?"

top_20 = videogame_sales_data.head(20)

top_20

# Most are Multiplatform and are mostly produced by Nintendo
# Out:
#     Unnamed: 0                                Title        Sales  \
# 0            0                            Minecraft  200,000,000
# 1            1                   Grand Theft Auto V  130,000,000
# 2            2                          Tetris (EA)  100,000,000
# 3            3                           Wii Sports   82,900,000
# 4            4        PlayerUnknown's Battlegrounds   60,000,000
# 5            5                    Super Mario Bros.   48,240,000
# 6            6  Pokémon Red / Green / Blue / Yellow   47,520,000
# 7            7             Wii Fit and Wii Fit Plus   43,800,000
# 8            8                    Tetris (Nintendo)   43,000,000
# 9            9                              Pac-Man   39,098,000
# 10          11                Mario Kart 8 / Deluxe   33,220,000
# 11          12                    Wii Sports Resort   33,130,000
# 12          13                Red Dead Redemption 2   31,000,000
# 13          14                New Super Mario Bros.   30,800,000
# 14          15                             Terraria   30,300,000
# 15          16            New Super Mario Bros. Wii   30,300,000
# 16          17          The Elder Scrolls V: Skyrim   30,000,000
# 17          18       Diablo III and Reaper of Souls   30,000,000
# 18          19      Pokémon Gold / Silver / Crystal   29,490,000
# 19          20                            Duck Hunt   28,300,000
#
#        Platform(s) Initial  release date            Developer(s)  \
# 0   Multi-platform  November 18, 2011[b]          Mojang Studios
# 1   Multi-platform             17-Sep-13          Rockstar North
# 2           Mobile             12-Sep-06               EA Mobile
# 3              Wii             19-Nov-06            Nintendo EAD
# 4   Multi-platform             20-Dec-17        PUBG Corporation
# 5   Multi-platform             13-Sep-85                Nintendo
# 6   Multi-platform             27-Feb-96              Game Freak
# 7              Wii              1-Dec-07            Nintendo EAD
# 8   Game Boy / NES             14-Jun-89           Nintendo R&D1
# 9   Multi-platform                Jul-80                   Namco
# 10  Wii U / Switch             29-May-14            Nintendo EAD
# 11             Wii             25-Jun-09            Nintendo EAD
# 12  Multi-platform             26-Oct-18        Rockstar Studios
# 13     Nintendo DS             15-May-06            Nintendo EAD
# 14  Multi-platform             16-May-11                Re-Logic
# 15             Wii             11-Nov-09            Nintendo EAD
# 16  Multi-platform             11-Nov-11   Bethesda Game Studios
# 17  Multi-platform             16-May-12  Blizzard Entertainment
# 18  Game Boy Color             21-Nov-99              Game Freak
# 19             NES             21-Apr-84           Nintendo R&D1
#
#               Publisher(s)
# 0           Mojang Studios
# 1           Rockstar Games
# 2          Electronic Arts
# 3                 Nintendo
# 4         PUBG Corporation
# 5                 Nintendo
# 6                 Nintendo
# 7                 Nintendo
# 8                 Nintendo
# 9                    Namco
# 10                Nintendo
# 11                Nintendo
# 12          Rockstar Games
# 13                Nintendo
# 14    Re-Logic / 505 Games
# 15                Nintendo
# 16      Bethesda Softworks
# 17  Blizzard Entertainment
# 18                Nintendo
# 19                Nintendo

# %%
"3.) Which company has produced the most video games?"

company = videogame_sales_data.iloc[:,6]
nintendo = company == 'Nintendo'
mojang = company == 'Mojang Studios'
rockstar = company == 'Rockstar Games'
ea = company == 'Electronic Arts'
pubg = company == 'PUBG Corporation'
namco = company == 'Namco'
relogic = company == 'Re-Logic / 505 Games'
bethesda = company == 'Bethesda Softworks'
blizzard = company == 'Blizzard Entertainment'
cd_projekt_red = company == 'CD Projekt'
xbox = company == 'Xbox Game Studios'
sega = company == 'Sega'
twok = company == '2K Games'
psygnosis = company == 'Psygnosis'
sony = company == 'Sony Computer Entertainment'
nintendo_pokemon = company == 'Nintendo / The Pokémon Company'

nintendo.sum(), mojang.sum(), rockstar.sum(), ea.sum(), pubg.sum(), namco.sum(), relogic.sum(), bethesda.sum(), blizzard.sum(), cd_projekt_red.sum(), xbox.sum(), sega.sum(), twok.sum(), psygnosis.sum(), sony.sum(), nintendo_pokemon.sum()

# Nintendo has produced the most games
# Out:
# (21, 1, 5, 2, 1, 1, 1, 1, 1, 1, 1, 2, 1, 1, 2, 3)

# %%
"4.) Which company has made the least amount of sales?"

for co in company:
    sales_dict[co] = videogame_sales_data.loc[videogame_sales_data["Publisher(s)"] == co]["Sales"].sum()

sales_dict

# Blizzaerd Entertainment and Bethesda Softwares has made the least amount of sales.
# Out:
# {'Mojang Studios': 200000000,
#  'Rockstar Games': 233500000,
#  'Electronic Arts': 124000000,
#  'Nintendo': 660263000,
#  'PUBG Corporation': 60000000,
#  'Namco': 39098000,
#  'Re-Logic / 505 Games': 30300000,
#  'Bethesda Softworks': 30000000,
#  'Blizzard Entertainment': 30000000,
#  'CD Projekt': 28000000,
#  'Activision': 118600000,
#  'Nintendo / The Pokémon Company': 72220000,
#  'Xbox Game Studios': 24000000,
#  'Sega': 43982960,
#  '2K Games': 22000000,
#  'Psygnosis': 20000000,
#  'Sony Computer Entertainment': 37830000}

# %%
"5.) Which company has made the least amount of games?"

company = videogame_sales_data.iloc[:,6]
nintendo = company == 'Nintendo'
mojang = company == 'Mojang Studios'
rockstar = company == 'Rockstar Games'
ea = company == 'Electronic Arts'
pubg = company == 'PUBG Corporation'
namco = company == 'Namco'
relogic = company == 'Re-Logic / 505 Games'
bethesda = company == 'Bethesda Softworks'
blizzard = company == 'Blizzard Entertainment'
cd_projekt_red = company == 'CD Projekt'
xbox = company == 'Xbox Game Studios'
sega = company == 'Sega'
twok = company == '2K Games'
psygnosis = company == 'Psygnosis'
sony = company == 'Sony Computer Entertainment'
nintendo_pokemon = company == 'Nintendo / The Pokémon Company'

nintendo.sum(), mojang.sum(), rockstar.sum(), ea.sum(), pubg.sum(), namco.sum(), relogic.sum(), bethesda.sum(), blizzard.sum(), cd_projekt_red.sum(), xbox.sum(), sega.sum(), twok.sum(), psygnosis.sum(), sony.sum(), nintendo_pokemon.sum()

# Mojang, EA, PUBG, Namco, Re-Logic / 505 Games, Bethesda Softworks, Blizzard Entertainment, CD Projekt, Sega, and 2K Games has made the least amount of games.
# Out:
# (21, 1, 5, 2, 1, 1, 1, 1, 1, 1, 1, 2, 1, 1, 2, 3)

# %%
"6.) Is being muliplatform compatible that impactful in terms of sales?"

multiplat_sales =

# %%
"7.) How many games are stuck to only one platform?"

one_platform =

# %%
"8.) How many games are multiplatform?"

multiplatform =

# %%
"9.) Which company is least likely to make the next big game?"

least_likely =

# %%
"10.) Which company would be most likely to make the next big game?"

most_likely =
# Out:
# array(['Mojang Studios', 'Rockstar Games', 'Electronic Arts', 'Nintendo',
#        'PUBG Corporation', 'Namco', 'Re-Logic / 505 Games',
#        'Bethesda Softworks', 'Blizzard Entertainment', 'CD Projekt',
#        'Activision', 'Nintendo / The Pokémon Company',
#        'Xbox Game Studios', 'Sega', '2K Games', 'Psygnosis',
#        'Sony Computer Entertainment'], dtype=object)
